# %%
import json
import re
import datetime

import ckanapi
import geopandas as gpd
import nltk
import numpy as np
import pandas as pd
import petk
import requests

from nltk.corpus import wordnet
from shapely.geometry import mapping, shape, Point, LineString, Polygon
from sklearn.preprocessing import MinMaxScaler

from datetime import datetime as dt
from time import sleep

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/ytan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
PACKAGE_FRAMEWORK = 'catalogue-quality-scores'

RESOURCE_METHODS = 'scoring-methods'
RESOURCE_SCORES = 'catalogue-scorecard'

MODEL_VERSION = 'v0.0.2'

DIMENSIONS = ['interpretability', 'usability', 'metadata', 'freshness', 'granularity', 'completeness', 'accessibility'] # Ordered by importance
METRICS = {
    'completeness': ['completeness'],
    'metadata': ['column_descriptions', 'dataset_metadata'],
    'usability': ['meaningful_names', 'non_constant_columns']
}

DATA_CKAN = {
    'address': 'https://ckanadmin0.intra.prod-toronto.ca',
#     'apikey': ''
}

STORAGE_CKAN = {
    'address': 'https://ckanadmin0.intra.dev-toronto.ca',
    'apikey': '784f11cc-b170-4377-83a3-38ba28662b16'
}

# %%
def get_model(ckan, pid=PACKAGE_FRAMEWORK):
    try:
        model = ckan.action.package_show(id=pid)
    except ckanapi.NotAuthorized:
        raise Exception('Permission required to search for the framework package')
    except ckanapi.NotFound:
        raise Exception('Framework package not found')
    
    return {
        r['name']: r for r in model.pop('resources')
    }

# %%
def read_datastore(ckan, rid, rows=10000):
    records = []
    
    is_geospatial = False
    
    has_more = True
    while has_more:
        result = ckan.action.datastore_search(id=rid, limit=rows, offset=len(records))
        
        records += result['records']
        has_more = len(records) < result['total']
    
    df = pd.DataFrame(records).drop('_id', axis=1)
    
    if 'geometry' in df.columns:
        df['geometry'] = df['geometry'].apply(lambda x: shape(json.loads(x)))
        
        df = gpd.GeoDataFrame(df, crs={'init': 'epsg:4326'})
    
    return df, [x for x in result['fields'] if x['id'] != '_id']

# %%
def load_data(ckan):
    packages = ckan.action.current_package_list_with_resources(limit=500)

    results = []
    for p in packages:
        metadata_fields = ['collection_method', 'limitations', 'civic_issues', 'topics', 'owner_division', 'owner_email']
        metadata_count = sum([1 if f in p and p[f] else 0 for f in metadata_fields])

        for r in p['resources']:
            if not 'datastore_active' in r or not r['datastore_active']:
                continue

            data, fields = read_datastore(ckan, r['id'])

            report = petk.DataReport(data)

            intro = report.introduce(as_dict=True)
            descr = report.describe(as_dict=True)

            fields_described, fields_meaningful = 0, 0
            for f in fields:
                if 'info' in f and f['info']['notes']:
                    fields_described += 1

                eng_words = [wordnet.synsets(x) for x in re.split('\s|_|-', f['id'])]
                if (len([x for x in eng_words if len(x)]) / len(eng_words)) > 0.8:
                    fields_meaningful += 1

            results.append({
                'package': p['name'],
                'resource': r['name'],
                'metrics': {
                    'dataset_metadata': metadata_count/len(metadata_fields),
                    'column_descriptions': 1 - (fields_described / len(fields)),
                    'completeness': 1 - (intro['observations']['missing'] / intro['observations']['total']),
                    'meaningful_names': 1 - (fields_meaningful / len(fields)),
                    'non_constant_columns': 1 - (len([x for x in descr['distinct_count'].values() if x == 1]) / len(descr['distinct_count'].values()))
                }
            })
    
    return results

# %%
def calculate_weights(dimensions, data, method='sr'):
    for i, row in enumerate(data):
        row['dimensions'] = {}
        for dim, fields in METRICS.items():
            scores = [ row['metrics'][x] for x in fields ]

            row[dim] = sum(scores)/len(scores)

    N = len(dimensions)
    
    if method == 'sr':
        denom = np.array([ ((1 / (i + 1)) + ((N + 1 - (i + 1)) / N)) for i, x in enumerate(dimensions) ]).sum()
        weights = [ ((1 / (i + 1)) + ((N + 1 - (i + 1)) / N)) / denom for i, x in enumerate(dimensions) ]
    elif method == 'rs':
        denom = np.array([ (N + 1 - (i + 1)) for i, x in enumerate(dimensions)]).sum()
        weights = [ (N + 1 - (i + 1)) / denom for i, x in enumerate(dimensions) ]
    elif method == 'rr':
        denom = np.array([ 1 / (i + 1) for i, x in enumerate(dimensions) ]).sum()
        weights = [ (1 / (i + 1)) / denom for i, x in enumerate(dimensions) ]
    elif method == 're':
        exp = 0.2
        denom = np.array([ (N + 1 - (i + 1)) ** exp for i, x in enumerate(dimensions) ]).sum()
        weights = [ (N + 1 - (i + 1)) ** exp / denom for i, x in enumerate(dimensions) ]
    else:
        raise Exception('Invalid weighting method provided')
    
    return weights

# %%
def update_model(ckan, model, storage):
    if not RESOURCE_METHODS in storage:
        r = requests.post(
            '{0}/api/3/action/resource_create'.format(ckan.address),
            data={
                'package_id': PACKAGE_FRAMEWORK,
                'name': RESOURCE_METHODS,
                'format': 'json',
                'is_preview': False
            },
            headers={
                'Authorization': ckan.apikey
            },
            files={
                'upload': ('{0}.json'.format(RESOURCE_METHODS), json.dumps({}))
            }
        )

        storage[RESOURCE_METHODS] = json.loads(r.content)['result']

    r = requests.get(
        storage[RESOURCE_METHODS]['url'],
        headers={
            'Authorization': ckan.apikey
        }
    )

    scoring_methods = json.loads(r.content)
    scoring_methods[MODEL_VERSION] = model

    r = requests.post(
        '{0}/api/3/action/resource_patch'.format(ckan.address),
        data={
            'id': storage[RESOURCE_METHODS]['id']
        },
        headers={
            'Authorization': ckan.apikey
        },
        files={
            'upload': ('{0}.json'.format(RESOURCE_METHODS), json.dumps(scoring_methods))
        }
    )

# %%
def update_score(ckan, data, weight, dimensions, storage):
    df = pd.DataFrame(data).set_index(['package', 'resource'])

    scores = pd.DataFrame([weight] * len(df.index))
    scores.index = df.index
    scores.columns = dimensions

    scores = df.multiply(scores)

    df['score'] = scores.sum(axis=1)
    df['score_norm'] = MinMaxScaler().fit_transform(df[['score']])

    df = df.groupby('package').mean()

    df['grade'] = pd.cut(df['score'], bins=[-1, .3, .5, .8, 1], labels=['D','C','B','A'])
    df['grade_norm'] = pd.cut(df['score_norm'], bins=[-1, .3, .5, .8, 1], labels=['D','C','B','A'])

    df['recorded_at'] = dt.now()
    df['model'] = MODEL_VERSION

    df = df.reset_index()

    report = petk.DataReport(df).describe(as_dict=True)

    ckan_fields = {
        'STRING': 'text',
        'NUMERIC': 'float',
        'DATE': 'timestamp'
    }

    fields = [
        {
            'id': k,
            'type': ckan_fields[v]
        } for k, v in report['content_type'].items()
    ]

    if not RESOURCE_SCORES in storage:
        storage[RESOURCE_SCORES] = ckan.action.datastore_create(
            resource={
                'package_id': PACKAGE_FRAMEWORK,
                'name': RESOURCE_SCORES,
                'format': 'csv',
                'is_preview': False
            },
            fields=fields,
            records=[]
        )

    df['recorded_at'] = df['recorded_at'].apply(lambda x: x.strftime('%Y-%m-%dT%H:%M:%SZ'))

    ckan.action.datastore_upsert(
        method='insert',
        resource_id=storage[RESOURCE_SCORES]['resource_id'],
        records=df.to_dict(orient='row')
    )

# %%
source = ckanapi.RemoteCKAN(**DATA_CKAN)
ckan = ckanapi.RemoteCKAN(**STORAGE_CKAN)

# %%
storage = get_model(ckan)

# %%
data = load_data(source)
# Out:
# /Users/ytan/miniconda3/envs/open-data/lib/python3.7/site-packages/petk/tools.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   'cv': series.std() / series.mean(),

# %%
dimensions = [ x for x in DIMENSIONS if x in METRICS ]
weights = calculate_weights(dimensions, data)

# %%
model = {
    'aggregation_methods': {
        'metrics_to_dimension': 'avg',
        'dimensions_to_score': 'sum_and_reciprocal'
    },
    'dimensions': [
        {
            'name': dim,
            'rank': i + 1,
            'weight': wgt,
            'metrics': METRICS[dim]
        } for i, (dim, wgt) in enumerate(zip(dimensions, weights))
    ]
}

update_model(ckan, model, storage)
update_score(ckan, data, weights, dimensions, storage)

# %%
records = []

is_geospatial = False

has_more = True
while has_more:
    result = source.action.datastore_search(id='b9214fd7-60d1-45f3-8463-a6bd9828f8bf', limit=5000, offset=len(records))

    records += result['records']
    has_more = len(records) < result['total']

df = pd.DataFrame(records).drop('_id', axis=1)

if 'geometry' in df.columns:
    df['geometry'] = df['geometry'].apply(lambda x: shape(json.loads(x)))

    df = gpd.GeoDataFrame(df, crs={'init': 'epsg:4326'})

# %%
test = source.action.datastore_search(id='b9214fd7-60d1-45f3-8463-a6bd9828f8bf', limit=100000)['records']
geometry=[Point(json.loads(x['geometry'])['coordinates']) for x in test]
test = gpd.GeoDataFrame(test, crs={'init': 'epsg:4326'}, geometry=geometry).drop(['_id', 'X', 'Y'], axis=1)
test.head()
# Out:
#   ADDRESSNUMBERTEXT   ADDRESSSTREET ASSETTYPE BARCODE            BIA  \
# 0                21       Redway Rd         A    None           None
# 1              2500  Sheppard Ave E         C    None           None
# 2               155      Culford Rd         A    None           None
# 3              5359     Dundas St W         B    None           None
# 4              3077       Weston Rd         C    None  Emery Village
#
#   DIRECTION      FROMSTREET     FRONTINGSTREET        ID   LATITUDE  ...  \
# 0     South    Overlea Blvd        Millwood Rd  SH-02236  43.701603  ...
# 1     North  Sheppard Ave E  Victoria Park Ave  SH-01079  43.775535  ...
# 2      East      Culford Rd     Lawrence Ave W  SH-01713  43.706311  ...
# 3      West      Poplar Ave        Dundas St W  SH-00626  43.635766  ...
# 4     North     Mainshep Rd          Weston Rd  SH-02437  43.731806  ...
#
#    OBJECTID  POSTERBOARD POSTERBOARDSTATUS SDE_STATE_ID   SIDE  SITEID  \
# 0         1           No              None            0   West   T2927
# 1         2           No              None            0   West   T7426
# 2         4           No              None            0  South   T5356
# 3         7          Yes          Existing            0  South   T2180
# 4         8           No              None            0   West  T11717
#
#      STATUS     STYLE WARD                                      geometry
# 0  Existing  Enseicom   15  POINT (-79.35256628671004 43.70160264566507)
# 1  Existing  Enseicom   17  POINT (-79.32335029056694 43.77553539676025)
# 2  Existing  Enseicom   05  POINT (-79.48732379138143 43.70631081680406)
# 3  Existing  Enseicom   03  POINT (-79.54014791139981 43.63576633196766)
# 4  Existing  Enseicom   07  POINT (-79.53779539502695 43.73180611693692)
#
# [5 rows x 21 columns]

# %%
test_report = petk.DataReport(df)

# %%
test_report.introduce(as_dict=True)
# Out:
# {'basic': {'memory_usage': 5922457, 'rows': 5684, 'columns': 23},
#  'observations': {'total': 130732, 'missing': 12766},
#  'columns': {'string': 16, 'numeric': 6, 'geometry': 1},
#  'geospatial': {'crs': 'epsg:4326',
#   'centroid_location': '-79.39585654203123, 43.72214759653589',
#   'bounds': array([-79.63465417,  43.59328834, -79.12309522,  43.83705657]),
#   '3d_shapes': 0,
#   'points': 5684}}

# %%
test_geo = test_report.describe(as_dict=True)
test_geo.keys()
# Out:
# dict_keys(['content_type', 'memory_usage', 'count', 'p_null', 'n_null', 'distinct_count', 'is_constant', 'is_unique', 'p_unique', 'min', 'max', '5%', '25%', '50%', '75%', '95%', 'mean', 'std', 'variance', 'iqr', 'kurtosis', 'skewness', 'sum', 'mad', 'cv', 'p_infinite', 'n_infinite', 'n_zeros', 'p_zeros'])

# %%
data
# Out:
# [{'package': 'bodysafe',
#   'resource': 'BodySafe Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.040000000000000036,
#    'completeness': 0.6892552324001087,
#    'meaningful_names': 0.84,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.6892552324001087,
#   'metadata': 0.27,
#   'usability': 0.9199999999999999},
#  {'package': 'street-furniture-transit-shelter',
#   'resource': 'Transit shelter data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9023498454854205,
#    'meaningful_names': 0.4782608695652174,
#    'non_constant_columns': 0.9565217391304348},
#   'dimensions': {},
#   'completeness': 0.9023498454854205,
#   'metadata': 0.75,
#   'usability': 0.7173913043478262},
#  {'package': 'street-furniture-publication-structure',
#   'resource': 'Publication structure data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9574085365853658,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.9},
#   'dimensions': {},
#   'completeness': 0.9574085365853658,
#   'metadata': 0.75,
#   'usability': 0.7},
#  {'package': 'street-furniture-public-washroom',
#   'resource': 'Public washroom data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9666666666666667,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.8},
#   'dimensions': {},
#   'completeness': 0.9666666666666667,
#   'metadata': 0.75,
#   'usability': 0.65},
#  {'package': 'street-furniture-poster-structure',
#   'resource': 'Poster structure data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9591549295774648,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.95},
#   'dimensions': {},
#   'completeness': 0.9591549295774648,
#   'metadata': 0.75,
#   'usability': 0.725},
#  {'package': 'street-furniture-poster-board',
#   'resource': 'Poster board data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.946407202689612,
#    'meaningful_names': 0.4782608695652174,
#    'non_constant_columns': 0.9130434782608696},
#   'dimensions': {},
#   'completeness': 0.946407202689612,
#   'metadata': 0.75,
#   'usability': 0.6956521739130435},
#  {'package': 'street-furniture-information-pillar-wayfinding-structure',
#   'resource': 'Street furniture-Information pillar data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9598837209302326,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.95},
#   'dimensions': {},
#   'completeness': 0.9598837209302326,
#   'metadata': 0.75,
#   'usability': 0.725},
#  {'package': 'street-furniture-bicycle-parking',
#   'resource': 'Street furniture-Bicycle parking data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.895511204745244,
#    'meaningful_names': 0.4736842105263158,
#    'non_constant_columns': 0.9473684210526316},
#   'dimensions': {},
#   'completeness': 0.895511204745244,
#   'metadata': 0.75,
#   'usability': 0.7105263157894737},
#  {'package': 'street-furniture-bench',
#   'resource': 'Street furniture-Bench data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9580684007707129,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.95},
#   'dimensions': {},
#   'completeness': 0.9580684007707129,
#   'metadata': 0.75,
#   'usability': 0.725},
#  {'package': 'polls-conducted-by-the-city',
#   'resource': 'Polls Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9886551155115512,
#    'meaningful_names': 0.16666666666666663,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9886551155115512,
#   'metadata': 0.75,
#   'usability': 0.5833333333333333},
#  {'package': 'chemical-tracking-chemtrac',
#   'resource': 'Chemical Tracking Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9,
#   'metadata': 0.75,
#   'usability': 0.75},
#  {'package': 'site-and-area-specific-policies',
#   'resource': 'Site and Area Specific Policies Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.06666666666666665,
#    'completeness': 0.5846860643185299,
#    'meaningful_names': 0.33333333333333337,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.5846860643185299,
#   'metadata': 0.2833333333333333,
#   'usability': 0.6666666666666667},
#  {'package': 'red-light-cameras',
#   'resource': 'Red Light Cameras Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.09999999999999998,
#    'completeness': 0.8,
#    'meaningful_names': 0.09999999999999998,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.8,
#   'metadata': 0.3,
#   'usability': 0.55},
#  {'package': 'police-boundaries',
#   'resource': 'Police Boundaries Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.06666666666666665,
#    'completeness': 0.8666666666666667,
#    'meaningful_names': 0.33333333333333337,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.8666666666666667,
#   'metadata': 0.2833333333333333,
#   'usability': 0.6666666666666667},
#  {'package': 'on-street-permit-parking-area-maps',
#   'resource': 'On-Street Permit Parking Area Map Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.040000000000000036,
#    'completeness': 0.36,
#    'meaningful_names': 0.31999999999999995,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.36,
#   'metadata': 0.27,
#   'usability': 0.6599999999999999},
#  {'package': 'bicycle-parking-bike-stations-indoor',
#   'resource': 'Bicycle Parking Data - Indoor',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7903225806451613,
#    'meaningful_names': 0.19354838709677424,
#    'non_constant_columns': 0.9032258064516129},
#   'dimensions': {},
#   'completeness': 0.7903225806451613,
#   'metadata': 0.75,
#   'usability': 0.5483870967741935},
#  {'package': 'bicycle-parking-high-capacity-outdoor',
#   'resource': 'Bicycle Parking Map Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.033333333333333326,
#    'completeness': 0.7663817663817664,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 0.9333333333333333},
#   'dimensions': {},
#   'completeness': 0.7663817663817664,
#   'metadata': 0.26666666666666666,
#   'usability': 0.5666666666666667},
#  {'package': 'neighbourhoods',
#   'resource': 'Neighbourhoods',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.06666666666666665,
#    'completeness': 0.8666666666666667,
#    'meaningful_names': 0.33333333333333337,
#    'non_constant_columns': 0.9333333333333333},
#   'dimensions': {},
#   'completeness': 0.8666666666666667,
#   'metadata': 0.2833333333333333,
#   'usability': 0.6333333333333333},
#  {'package': 'former-municipality-boundaries',
#   'resource': 'Former Municipality Boundaries Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.8125,
#    'meaningful_names': 0.3125,
#    'non_constant_columns': 0.9375},
#   'dimensions': {},
#   'completeness': 0.8125,
#   'metadata': 0.75,
#   'usability': 0.625},
#  {'package': 'city-wards',
#   'resource': 'City Wards Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.040000000000000036,
#    'completeness': 0.72,
#    'meaningful_names': 0.31999999999999995,
#    'non_constant_columns': 0.76},
#   'dimensions': {},
#   'completeness': 0.72,
#   'metadata': 0.27,
#   'usability': 0.54},
#  {'package': 'business-improvement-areas',
#   'resource': 'Business Improvement Areas Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0625,
#    'completeness': 0.9375,
#    'meaningful_names': 0.3125,
#    'non_constant_columns': 0.9375},
#   'dimensions': {},
#   'completeness': 0.9375,
#   'metadata': 0.28125,
#   'usability': 0.625},
#  {'package': 'community-council-boundaries',
#   'resource': 'Community Council Boundaries Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.06666666666666665,
#    'completeness': 0.9333333333333333,
#    'meaningful_names': 0.33333333333333337,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9333333333333333,
#   'metadata': 0.2833333333333333,
#   'usability': 0.6666666666666667},
#  {'package': 'highrise-residential-fire-inspection-results',
#   'resource': 'Highrise Inspections Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 0.936041283028564,
#    'meaningful_names': 0.75,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.936041283028564,
#   'metadata': 0.25,
#   'usability': 0.875},
#  {'package': 'fire-incidents',
#   'resource': 'Fire Incidents Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 0.8784939214118689,
#    'meaningful_names': 0.33333333333333337,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.8784939214118689,
#   'metadata': 0.25,
#   'usability': 0.6666666666666667},
#  {'package': 'building-permits-solar-hot-water-heaters',
#   'resource': 'Solar Hot Water Heater Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9821138211382113,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 0.8},
#   'dimensions': {},
#   'completeness': 0.9821138211382113,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'building-permits-signs',
#   'resource': 'sign-permit-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9752651483628765,
#    'meaningful_names': 0.15384615384615385,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9752651483628765,
#   'metadata': 0.75,
#   'usability': 0.5769230769230769},
#  {'package': 'building-permits-signs',
#   'resource': 'Building Permits - Signs Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9474178479122854,
#    'meaningful_names': 0.2142857142857143,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9474178479122854,
#   'metadata': 0.75,
#   'usability': 0.6071428571428572},
#  {'package': 'building-permits-pool-enclosures',
#   'resource': 'Building Permits - Pool Enclosures Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9924447729325778,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9924447729325778,
#   'metadata': 0.75,
#   'usability': 0.6},
#  {'package': 'building-permits-green-roofs',
#   'resource': 'toronto-building-green-roof-permits-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9070024077046549,
#    'meaningful_names': 0.1875,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9070024077046549,
#   'metadata': 0.75,
#   'usability': 0.59375},
#  {'package': 'building-permits-green-roofs',
#   'resource': 'Building Permits - Green Roofs Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9172821270310192,
#    'meaningful_names': 0.1875,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9172821270310192,
#   'metadata': 0.75,
#   'usability': 0.59375},
#  {'package': 'bicycle-parking-racks',
#   'resource': 'Bicycle Parking Racks Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.8449515905947441,
#    'meaningful_names': 0.2666666666666667,
#    'non_constant_columns': 0.9},
#   'dimensions': {},
#   'completeness': 0.8449515905947441,
#   'metadata': 0.75,
#   'usability': 0.5833333333333334},
#  {'package': 'residential-front-yard-parking',
#   'resource': 'Residential Front Yard Parking Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.4,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.25,
#   'usability': 0.7},
#  {'package': 'street-furniture-litter-receptacle',
#   'resource': 'Street furniture-Litter receptacle data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9545917338709677,
#    'meaningful_names': 0.5,
#    'non_constant_columns': 0.95},
#   'dimensions': {},
#   'completeness': 0.9545917338709677,
#   'metadata': 0.75,
#   'usability': 0.725},
#  {'package': 'apartment-building-registration',
#   'resource': 'Apartment Building Registration Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 0.9459916835895948,
#    'meaningful_names': 0.3055555555555556,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9459916835895948,
#   'metadata': 0.25,
#   'usability': 0.6527777777777778},
#  {'package': 'development-applications',
#   'resource': 'Development Applications Data',
#   'metrics': {'dataset_metadata': 0.6666666666666666,
#    'column_descriptions': 0.0,
#    'completeness': 0.9633403777409839,
#    'meaningful_names': 0.2142857142857143,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9633403777409839,
#   'metadata': 0.3333333333333333,
#   'usability': 0.6071428571428572},
#  {'package': 'school-locations-all-types',
#   'resource': 'School locations-all types data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.8340629502382799,
#    'meaningful_names': 0.2857142857142857,
#    'non_constant_columns': 0.9285714285714286},
#   'dimensions': {},
#   'completeness': 0.8340629502382799,
#   'metadata': 0.75,
#   'usability': 0.6071428571428572},
#  {'package': 'marriage-licence-statistics',
#   'resource': 'Marriage Licence Statistics Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.25,
#   'usability': 0.5},
#  {'package': 'stillbirth-registration-statistics',
#   'resource': 'Stillbirth Registration Statistics Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 0.6666666666666667},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.25,
#   'usability': 0.33333333333333337},
#  {'package': 'death-registry-statistics',
#   'resource': 'Death Registry Statistics Data',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.25,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.25,
#   'usability': 0.625},
#  {'package': 'doors-open-toronto-2018',
#   'resource': 'doors-open-2018-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.6284648187633262,
#    'meaningful_names': 0.1785714285714286,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.6284648187633262,
#   'metadata': 0.75,
#   'usability': 0.5892857142857143},
#  {'package': 'air-conditioned-public-places-cooling-centres',
#   'resource': 'air-conditioned-public-places-and-cooling-centres-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9028248587570622,
#    'meaningful_names': 0.30000000000000004,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9028248587570622,
#   'metadata': 0.75,
#   'usability': 0.65},
#  {'package': 'municipal-licensing-and-standards-business-licences-and-permits',
#   'resource': 'business-licences',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.6485549830440478,
#    'meaningful_names': 0.0625,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.6485549830440478,
#   'metadata': 0.75,
#   'usability': 0.53125},
#  {'package': 'members-of-toronto-city-council-voting-record',
#   'resource': 'member-voting-record-2006-2010',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.6},
#  {'package': 'members-of-toronto-city-council-voting-record',
#   'resource': 'member-voting-record-2010-2014',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.6},
#  {'package': 'members-of-toronto-city-council-voting-record',
#   'resource': 'member-voting-record-2014-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.19999999999999996,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.6},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'traffic-signals-all-version-1-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.708498023715415,
#    'meaningful_names': 0.17391304347826086,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.708498023715415,
#   'metadata': 0.75,
#   'usability': 0.5869565217391304},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'traffic-signals-all-version-2-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.807195518402415,
#    'meaningful_names': 0.24137931034482762,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.807195518402415,
#   'metadata': 0.75,
#   'usability': 0.6206896551724138},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'traffic-signals-aps-version-1-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.736842105263158,
#    'meaningful_names': 0.17391304347826086,
#    'non_constant_columns': 0.9130434782608696},
#   'dimensions': {},
#   'completeness': 0.736842105263158,
#   'metadata': 0.75,
#   'usability': 0.5434782608695652},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'traffic-signals-aps-version-2-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.8473844240204547,
#    'meaningful_names': 0.24137931034482762,
#    'non_constant_columns': 0.9310344827586207},
#   'dimensions': {},
#   'completeness': 0.8473844240204547,
#   'metadata': 0.75,
#   'usability': 0.5862068965517242},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'flashing-beacons-version-1-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7368067978533095,
#    'meaningful_names': 0.07692307692307687,
#    'non_constant_columns': 0.9230769230769231},
#   'dimensions': {},
#   'completeness': 0.7368067978533095,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'flashing-beacons-version-2-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7556063122923589,
#    'meaningful_names': 0.0714285714285714,
#    'non_constant_columns': 0.9285714285714286},
#   'dimensions': {},
#   'completeness': 0.7556063122923589,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'pedestrian-crossovers-version-1-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7496794871794872,
#    'meaningful_names': 0.07692307692307687,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.7496794871794872,
#   'metadata': 0.75,
#   'usability': 0.5384615384615384},
#  {'package': 'traffic-signals-tabular',
#   'resource': 'pedestrian-crossovers-version-2-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7675595238095239,
#    'meaningful_names': 0.0714285714285714,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.7675595238095239,
#   'metadata': 0.75,
#   'usability': 0.5357142857142857},
#  {'package': 'traffic-cameras',
#   'resource': 'traffic-camera-list-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9938311688311688,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9938311688311688,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'solid-waste-pickup-schedule',
#   'resource': 'pickup-schedule-2019-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'solid-waste-pickup-schedule',
#   'resource': 'pickup-schedule-2018-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5714285714285714,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7857142857142857},
#  {'package': 'solid-waste-pickup-schedule',
#   'resource': 'pickup-schedule-2017-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5714285714285714,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7857142857142857},
#  {'package': 'solid-waste-pickup-schedule',
#   'resource': 'pickup-schedule-2016-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5714285714285714,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7857142857142857},
#  {'package': 'solid-waste-pickup-schedule',
#   'resource': 'pickup-schedule-sept2014-dec-2015-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5714285714285714,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7857142857142857},
#  {'package': 'secondary-plans',
#   'resource': 'Secondary Plans Data 2017',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 0.09090909090909094,
#    'completeness': 0.7313131313131314,
#    'meaningful_names': 0.2727272727272727,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.7313131313131314,
#   'metadata': 0.29545454545454547,
#   'usability': 0.6363636363636364},
#  {'package': 'bicycle-shops',
#   'resource': 'Bicycle Shops Data',
#   'metrics': {'dataset_metadata': 0.6666666666666666,
#    'column_descriptions': 1.0,
#    'completeness': 0.7481778425655976,
#    'meaningful_names': 0.2142857142857143,
#    'non_constant_columns': 0.8928571428571429},
#   'dimensions': {},
#   'completeness': 0.7481778425655976,
#   'metadata': 0.8333333333333333,
#   'usability': 0.5535714285714286},
#  {'package': 'registry-of-declared-interest',
#   'resource': 'declared-interest-2014-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7779995564426703,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 0.8888888888888888},
#   'dimensions': {},
#   'completeness': 0.7779995564426703,
#   'metadata': 0.75,
#   'usability': 0.4444444444444444},
#  {'package': 'registry-of-declared-interest',
#   'resource': 'declared-interest-2010-2014',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7777777777777778,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.7777777777777778,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'registry-of-declared-interest',
#   'resource': 'declared-interest-2006-2010',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.7777777777777778,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.7777777777777778,
#   'metadata': 0.75,
#   'usability': 0.5},
#  {'package': 'neighbourhood-profiles',
#   'resource': 'neighbourhood-profiles-2016-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.7103448275862069,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.8551724137931034},
#  {'package': 'neighbourhood-profiles',
#   'resource': 'neighbourhood-profiles-2016-readme',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9285714285714286,
#    'meaningful_names': 1.0,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9285714285714286,
#   'metadata': 0.75,
#   'usability': 1.0},
#  {'package': 'members-of-toronto-city-council-meeting-attendance',
#   'resource': 'councillors-meeting-attendance-2006-2010',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.125,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5625},
#  {'package': 'members-of-toronto-city-council-meeting-attendance',
#   'resource': 'councillors-meeting-attendance-2010-2014',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.125,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5625},
#  {'package': 'members-of-toronto-city-council-meeting-attendance',
#   'resource': 'councillors-meeting-attendance-2014-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.125,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5625},
#  {'package': 'licensed-child-care-centres',
#   'resource': 'licensed-day-care-centres-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9456709956709957,
#    'meaningful_names': 0.5909090909090908,
#    'non_constant_columns': 0.9545454545454546},
#   'dimensions': {},
#   'completeness': 0.9456709956709957,
#   'metadata': 0.75,
#   'usability': 0.7727272727272727},
#  {'package': 'king-st-transit-pilot-bluetooth-travel-time-summary',
#   'resource': 'bluetooth-travel-time-summary',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.2222222222222222,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.6111111111111112},
#  {'package': 'king-st-transit-pilot-traffic-pedestrian-volumes-summary',
#   'resource': 'king-st-pilot-traffic-pedestrian-volumes-summary',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.25,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.625},
#  {'package': 'king-st-transit-pilot-2015-king-street-traffic-counts',
#   'resource': '2015-king-street-traffic-counts-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.6666666666666667,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.8333333333333334},
#  {'package': 'immunization-coverage-for-students',
#   'resource': 'immunization-coverage-2017-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9969173859432799,
#    'meaningful_names': 0.6666666666666667,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.9969173859432799,
#   'metadata': 0.75,
#   'usability': 0.8333333333333334},
#  {'package': 'doors-open-toronto-2017',
#   'resource': 'doors-open-2017',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.6284648187633262,
#    'meaningful_names': 0.1785714285714286,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.6284648187633262,
#   'metadata': 0.75,
#   'usability': 0.5892857142857143},
#  {'package': 'doors-open-toronto-2016',
#   'resource': 'doors-open-2016-static-csv-as-of-may-24th-2016',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.6145940390544706,
#    'meaningful_names': 0.1785714285714286,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.6145940390544706,
#   'metadata': 0.75,
#   'usability': 0.5892857142857143},
#  {'package': 'daily-shelter-occupancy',
#   'resource': 'daily-shelter-occupancy-2017-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9938587424633937,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 0.9166666666666666},
#   'dimensions': {},
#   'completeness': 0.9938587424633937,
#   'metadata': 0.75,
#   'usability': 0.4583333333333333},
#  {'package': 'daily-shelter-occupancy',
#   'resource': 'daily-shelter-occupancy-2018-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9935574971317624,
#    'meaningful_names': 0.0,
#    'non_constant_columns': 0.9166666666666666},
#   'dimensions': {},
#   'completeness': 0.9935574971317624,
#   'metadata': 0.75,
#   'usability': 0.4583333333333333},
#  {'package': 'councillors-constituency-services-office-expense-reporting',
#   'resource': 'councillors-office-expenses-2013',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.5972222222222222,
#    'meaningful_names': 0.5333333333333333,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 0.5972222222222222,
#   'metadata': 0.75,
#   'usability': 0.7666666666666666},
#  {'package': 'council-and-standing-committee-meeting-statistics',
#   'resource': 'council-and-standing-committee-meeting-statistics-data-2010-2014',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5454545454545454,
#    'non_constant_columns': 0.9090909090909091},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7272727272727273},
#  {'package': 'council-and-standing-committee-meeting-statistics',
#   'resource': 'council-and-standing-committee-meeting-statistics-data-2014-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.5454545454545454,
#    'non_constant_columns': 0.9090909090909091},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.7272727272727273},
#  {'package': 'city-of-toronto-mbncanada-performance-measures',
#   'resource': 'mbncanada-performance-measures-2016-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9466101694915254,
#    'meaningful_names': 0.0714285714285714,
#    'non_constant_columns': 0.7142857142857143},
#   'dimensions': {},
#   'completeness': 0.9466101694915254,
#   'metadata': 0.75,
#   'usability': 0.39285714285714285},
#  {'package': 'city-of-toronto-mbncanada-performance-measures',
#   'resource': 'mbncanada-performance-measures-2017-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.9480077745383868,
#    'meaningful_names': 0.0714285714285714,
#    'non_constant_columns': 0.7142857142857143},
#   'dimensions': {},
#   'completeness': 0.9480077745383868,
#   'metadata': 0.75,
#   'usability': 0.39285714285714285},
#  {'package': 'city-council-and-committees-meeting-schedule-reports',
#   'resource': 'meeting-schedule-all-committees-2014-2018',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.16666666666666663,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5833333333333333},
#  {'package': 'city-council-and-committees-meeting-schedule-reports',
#   'resource': 'meeting-schedule-all-committees-2010-2014',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.16666666666666663,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5833333333333333},
#  {'package': 'city-council-and-committees-meeting-schedule-reports',
#   'resource': 'meeting-schedule-all-committees-2006-2010',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 1.0,
#    'meaningful_names': 0.16666666666666663,
#    'non_constant_columns': 1.0},
#   'dimensions': {},
#   'completeness': 1.0,
#   'metadata': 0.75,
#   'usability': 0.5833333333333333},
#  {'package': 'business-incubation',
#   'resource': 'business-incubation-csv',
#   'metrics': {'dataset_metadata': 0.5,
#    'column_descriptions': 1.0,
#    'completeness': 0.8894230769230769,
#    'meaningful_names': 0.125,
#    'non_constant_columns': 0.875},
#   'dimensions': {},
#   'completeness': 0.8894230769230769,
#   'metadata': 0.75,
#   'usability': 0.5}]
